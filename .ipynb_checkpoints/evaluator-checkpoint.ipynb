# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Imports

# %%
import cv2
import math
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import tensorflow as tf

from sklearn.metrics import mean_squared_error
from tabulate import tabulate
from tensorflow.python.keras.models import load_model
from wavetf._haar_conv import HaarWaveLayer2D, InvHaarWaveLayer2D

from attacks.gaussian_noise_attack import gaussian_noise_function
from attacks.rotation_attack import rotation_function
from attacks.salt_pepper_attack import salt_pepper_function
from attacks.stupid_attack import stupid_function
from data_loaders.attack_id_data_loader.tensor_flow_attack_id_data_loader import TensorFlowAttackIdDataLoader
from data_loaders.image_data_loaders.tensor_flow_image_data_loader import TensorFlowImageDataLoader
from data_loaders.watermark_data_loaders.tensor_flow_watermark_data_loader import TensorFlowWatermarkDataLoader
# Out:
# 2022-07-22 16:50:05.853424: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ### Configs

# %%
TEST_IMAGES_PATH = 'test_images/'
MODEL_PATH = 'pure_wavelet/'

SAMPLE_IMAGES_OUTPUT = 'sample_outputs/'

IMAGE_SIZE = (256, 256, 1)
WATERMARK_SIZE = (16 * 16,)
BATCH_SIZE = 10

ATTACKS = [
    'stupid_attack',
    'salt_pepper_attack',
    'gaussian_noise_attack',
    'rotation_attack'
]

# %% [markdown]
# ## Preparations

# %% [markdown]
# ### Prepare datasets

# %%
test_data_loaders = {}
for attack_id, attack in enumerate(ATTACKS):
    image_data_loader = TensorFlowImageDataLoader(
        base_path=TEST_IMAGES_PATH,
        channels=[0],
        convert_type=tf.float32
    ).get_data_loader()
    watermark_data_loader = TensorFlowWatermarkDataLoader(
        watermark_size=WATERMARK_SIZE
    ).get_data_loader()
    attack_id_data_loader = TensorFlowAttackIdDataLoader(
        min_value=attack_id,
        max_value=attack_id+1
    ).get_data_loader()
    
    input_data_loader = tf.data.Dataset.zip((
        image_data_loader,
        watermark_data_loader,
        attack_id_data_loader,
    ))
    input_data_loader = input_data_loader.batch(BATCH_SIZE)
    input_data_loader = input_data_loader.prefetch(1)
    test_data_loaders[attack] = input_data_loader
# Out:
# 2022-07-22 16:50:06.929499: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-07-22 16:50:08.621536: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-22 16:50:08.621586: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (zenbook-ux533fn): /proc/driver/nvidia/version does not exist
# 2022-07-22 16:50:08.623307: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Load model

# %% [markdown]
# #### Select model

# %%
def model_selector(model_path=MODEL_PATH):
    model_names_list = sorted(os.listdir(model_path))
    for idx, model_name in enumerate(model_names_list):
        print(idx, model_name)
    selected_idx = int(input('Model number: '))
    return model_names_list[selected_idx]

model_name = model_selector()
print(f'selected model is {model_name}')
# Out:
# 0 epochs:001-embedded_image_loss:0.003707045-output_watermark_loss:0.171661437.hdf5
# 1 epochs:002-embedded_image_loss:0.001437914-output_watermark_loss:0.143709108.hdf5
# 2 epochs:003-embedded_image_loss:0.000957946-output_watermark_loss:0.133686990.hdf5
# 3 epochs:004-embedded_image_loss:0.000702425-output_watermark_loss:0.129191205.hdf5
# 4 epochs:005-embedded_image_loss:0.000548875-output_watermark_loss:0.133303821.hdf5
# 5 epochs:006-embedded_image_loss:0.000435240-output_watermark_loss:0.132980868.hdf5
# 6 epochs:007-embedded_image_loss:0.000366539-output_watermark_loss:0.125137404.hdf5
# 7 epochs:008-embedded_image_loss:0.000326768-output_watermark_loss:0.131531283.hdf5
# 8 epochs:009-embedded_image_loss:0.000299810-output_watermark_loss:0.128762677.hdf5
# 9 epochs:010-embedded_image_loss:0.000277588-output_watermark_loss:0.124729156.hdf5
# 10 epochs:011-embedded_image_loss:0.000259665-output_watermark_loss:0.120151870.hdf5
# 11 epochs:012-embedded_image_loss:0.000248334-output_watermark_loss:0.121853456.hdf5
# 12 epochs:013-embedded_image_loss:0.000227720-output_watermark_loss:0.129515007.hdf5
# 13 epochs:014-embedded_image_loss:0.000228587-output_watermark_loss:0.122108519.hdf5
# 14 epochs:015-embedded_image_loss:0.000218904-output_watermark_loss:0.123968072.hdf5
# 15 epochs:016-embedded_image_loss:0.000210502-output_watermark_loss:0.127564564.hdf5
# 16 epochs:017-embedded_image_loss:0.000205653-output_watermark_loss:0.131566569.hdf5
# 17 epochs:018-embedded_image_loss:0.000204403-output_watermark_loss:0.117064700.hdf5
# 18 epochs:019-embedded_image_loss:0.000196847-output_watermark_loss:0.121965833.hdf5
# 19 epochs:020-embedded_image_loss:0.000193983-output_watermark_loss:0.126538932.hdf5
# 20 epochs:021-embedded_image_loss:0.000193709-output_watermark_loss:0.126471609.hdf5
# 21 epochs:022-embedded_image_loss:0.000190123-output_watermark_loss:0.121750966.hdf5
# 22 epochs:023-embedded_image_loss:0.000185836-output_watermark_loss:0.128245294.hdf5
# 23 epochs:024-embedded_image_loss:0.000188218-output_watermark_loss:0.121192537.hdf5
# 24 epochs:025-embedded_image_loss:0.000184570-output_watermark_loss:0.123749845.hdf5
# 25 epochs:026-embedded_image_loss:0.000181928-output_watermark_loss:0.126526356.hdf5
# 26 epochs:027-embedded_image_loss:0.000181201-output_watermark_loss:0.123405226.hdf5
# 27 epochs:028-embedded_image_loss:0.000180960-output_watermark_loss:0.122775249.hdf5
# 28 epochs:029-embedded_image_loss:0.000181333-output_watermark_loss:0.129519179.hdf5
# 29 epochs:030-embedded_image_loss:0.000177902-output_watermark_loss:0.122321405.hdf5
# 30 epochs:031-embedded_image_loss:0.000172780-output_watermark_loss:0.124028295.hdf5
# 31 epochs:032-embedded_image_loss:0.000173108-output_watermark_loss:0.126031861.hdf5
# 32 epochs:033-embedded_image_loss:0.000171707-output_watermark_loss:0.125093386.hdf5
# 33 epochs:034-embedded_image_loss:0.000172389-output_watermark_loss:0.119633019.hdf5
# 34 epochs:035-embedded_image_loss:0.000171301-output_watermark_loss:0.125424504.hdf5
# 35 epochs:036-embedded_image_loss:0.000171838-output_watermark_loss:0.122627832.hdf5
# 36 epochs:037-embedded_image_loss:0.000173317-output_watermark_loss:0.124632023.hdf5
# 37 epochs:038-embedded_image_loss:0.000170319-output_watermark_loss:0.119200625.hdf5
# 38 epochs:039-embedded_image_loss:0.000168495-output_watermark_loss:0.121682025.hdf5
# 39 epochs:040-embedded_image_loss:0.000168990-output_watermark_loss:0.123476066.hdf5
# 40 epochs:041-embedded_image_loss:0.000168993-output_watermark_loss:0.117837660.hdf5
# 41 epochs:042-embedded_image_loss:0.000166871-output_watermark_loss:0.119017579.hdf5
# 42 epochs:043-embedded_image_loss:0.000164903-output_watermark_loss:0.117857970.hdf5
# 43 epochs:044-embedded_image_loss:0.000166925-output_watermark_loss:0.121745825.hdf5
# 44 epochs:045-embedded_image_loss:0.000162161-output_watermark_loss:0.120232850.hdf5
# 45 epochs:046-embedded_image_loss:0.000167547-output_watermark_loss:0.115631640.hdf5
# 46 epochs:047-embedded_image_loss:0.000164434-output_watermark_loss:0.123340502.hdf5
# 47 epochs:048-embedded_image_loss:0.000165625-output_watermark_loss:0.114306569.hdf5
# 48 epochs:049-embedded_image_loss:0.000162368-output_watermark_loss:0.121664681.hdf5
# 49 epochs:050-embedded_image_loss:0.000160546-output_watermark_loss:0.120236471.hdf5
# 50 epochs:051-embedded_image_loss:0.000162330-output_watermark_loss:0.122626998.hdf5
# 51 epochs:052-embedded_image_loss:0.000163100-output_watermark_loss:0.116448529.hdf5
# 52 epochs:053-embedded_image_loss:0.000163797-output_watermark_loss:0.123586886.hdf5
# 53 epochs:054-embedded_image_loss:0.000158952-output_watermark_loss:0.122370303.hdf5
# 54 epochs:055-embedded_image_loss:0.000157751-output_watermark_loss:0.120031103.hdf5
# 55 epochs:056-embedded_image_loss:0.000161117-output_watermark_loss:0.123854764.hdf5
# 56 epochs:057-embedded_image_loss:0.000155412-output_watermark_loss:0.123414092.hdf5
# 57 epochs:058-embedded_image_loss:0.000157162-output_watermark_loss:0.117510915.hdf5
# 58 epochs:059-embedded_image_loss:0.000155308-output_watermark_loss:0.118274920.hdf5
# 59 epochs:060-embedded_image_loss:0.000156659-output_watermark_loss:0.126287133.hdf5
# 60 epochs:061-embedded_image_loss:0.000159550-output_watermark_loss:0.120750599.hdf5
# 61 epochs:062-embedded_image_loss:0.000157375-output_watermark_loss:0.124152735.hdf5
# 62 epochs:063-embedded_image_loss:0.000156762-output_watermark_loss:0.121962205.hdf5
# 63 epochs:064-embedded_image_loss:0.000155351-output_watermark_loss:0.121133998.hdf5
# 64 epochs:065-embedded_image_loss:0.000157440-output_watermark_loss:0.120278530.hdf5
# 65 epochs:066-embedded_image_loss:0.000159110-output_watermark_loss:0.116039984.hdf5
# 66 epochs:067-embedded_image_loss:0.000157072-output_watermark_loss:0.120817244.hdf5
# 67 epochs:068-embedded_image_loss:0.000152160-output_watermark_loss:0.122420840.hdf5
# 68 epochs:069-embedded_image_loss:0.000156004-output_watermark_loss:0.124003388.hdf5
# 69 epochs:070-embedded_image_loss:0.000154621-output_watermark_loss:0.127867579.hdf5
# 70 epochs:071-embedded_image_loss:0.000155043-output_watermark_loss:0.121002056.hdf5
# 71 epochs:072-embedded_image_loss:0.000156475-output_watermark_loss:0.117824696.hdf5
# 72 epochs:073-embedded_image_loss:0.000155833-output_watermark_loss:0.121474288.hdf5
# 73 epochs:074-embedded_image_loss:0.000152154-output_watermark_loss:0.121665351.hdf5
# 74 epochs:075-embedded_image_loss:0.000154031-output_watermark_loss:0.128002122.hdf5
# 75 epochs:076-embedded_image_loss:0.000154827-output_watermark_loss:0.118214920.hdf5
# 76 epochs:077-embedded_image_loss:0.000153933-output_watermark_loss:0.120919816.hdf5
# 77 epochs:078-embedded_image_loss:0.000152952-output_watermark_loss:0.121058978.hdf5
# 78 epochs:079-embedded_image_loss:0.000153287-output_watermark_loss:0.126920521.hdf5
# 79 epochs:080-embedded_image_loss:0.000153982-output_watermark_loss:0.121524535.hdf5
# 80 epochs:081-embedded_image_loss:0.000153637-output_watermark_loss:0.118672185.hdf5
# 81 epochs:082-embedded_image_loss:0.000154291-output_watermark_loss:0.121449977.hdf5
# 82 epochs:083-embedded_image_loss:0.000152755-output_watermark_loss:0.122055657.hdf5
# 83 epochs:084-embedded_image_loss:0.000150800-output_watermark_loss:0.119552635.hdf5
# 84 epochs:085-embedded_image_loss:0.000148347-output_watermark_loss:0.120538674.hdf5
# 85 epochs:086-embedded_image_loss:0.000151940-output_watermark_loss:0.118299067.hdf5
# 86 epochs:087-embedded_image_loss:0.000152141-output_watermark_loss:0.116718881.hdf5
# 87 epochs:088-embedded_image_loss:0.000151559-output_watermark_loss:0.124919429.hdf5
# 88 epochs:089-embedded_image_loss:0.000152328-output_watermark_loss:0.121992752.hdf5
# 89 epochs:090-embedded_image_loss:0.000149074-output_watermark_loss:0.122623026.hdf5
# 90 epochs:091-embedded_image_loss:0.000151333-output_watermark_loss:0.118467741.hdf5
# 91 epochs:092-embedded_image_loss:0.000151328-output_watermark_loss:0.127397820.hdf5
# 92 epochs:093-embedded_image_loss:0.000148744-output_watermark_loss:0.124294601.hdf5
# 93 epochs:094-embedded_image_loss:0.000146454-output_watermark_loss:0.122458257.hdf5
# 94 epochs:095-embedded_image_loss:0.000149799-output_watermark_loss:0.123398162.hdf5
# 95 epochs:096-embedded_image_loss:0.000149237-output_watermark_loss:0.118184164.hdf5
# 96 epochs:097-embedded_image_loss:0.000147754-output_watermark_loss:0.119147465.hdf5
# 97 epochs:098-embedded_image_loss:0.000150515-output_watermark_loss:0.117846720.hdf5
# 98 epochs:099-embedded_image_loss:0.000150508-output_watermark_loss:0.123230956.hdf5
# 99 epochs:100-embedded_image_loss:0.000147989-output_watermark_loss:0.122702710.hdf5
# 100 epochs:101-embedded_image_loss:0.000147449-output_watermark_loss:0.121348388.hdf5
# 101 epochs:102-embedded_image_loss:0.000145012-output_watermark_loss:0.121742651.hdf5
# 102 epochs:103-embedded_image_loss:0.000144880-output_watermark_loss:0.123904288.hdf5
# 103 epochs:104-embedded_image_loss:0.000145334-output_watermark_loss:0.118978702.hdf5
# 104 epochs:105-embedded_image_loss:0.000148427-output_watermark_loss:0.117980443.hdf5
# 105 epochs:106-embedded_image_loss:0.000150111-output_watermark_loss:0.120533936.hdf5
# 106 epochs:107-embedded_image_loss:0.000146566-output_watermark_loss:0.125815853.hdf5
# 107 epochs:108-embedded_image_loss:0.000148630-output_watermark_loss:0.117461905.hdf5
# 108 epochs:109-embedded_image_loss:0.000146587-output_watermark_loss:0.122490413.hdf5
# 109 epochs:110-embedded_image_loss:0.000146000-output_watermark_loss:0.122415133.hdf5
# 110 epochs:111-embedded_image_loss:0.000149212-output_watermark_loss:0.119821593.hdf5
# 111 epochs:112-embedded_image_loss:0.000148417-output_watermark_loss:0.117334805.hdf5
# 112 epochs:113-embedded_image_loss:0.000144956-output_watermark_loss:0.123043701.hdf5
# 113 epochs:114-embedded_image_loss:0.000149770-output_watermark_loss:0.118934877.hdf5
# 114 epochs:115-embedded_image_loss:0.000148707-output_watermark_loss:0.123433813.hdf5
# 115 epochs:116-embedded_image_loss:0.000145537-output_watermark_loss:0.123328336.hdf5
# 116 epochs:117-embedded_image_loss:0.000147511-output_watermark_loss:0.123881944.hdf5
# 117 epochs:118-embedded_image_loss:0.000146527-output_watermark_loss:0.116855592.hdf5
# 118 epochs:119-embedded_image_loss:0.000149444-output_watermark_loss:0.116833389.hdf5
# 119 epochs:120-embedded_image_loss:0.000145622-output_watermark_loss:0.120416529.hdf5
# 120 epochs:121-embedded_image_loss:0.000146008-output_watermark_loss:0.120537937.hdf5
# 121 epochs:122-embedded_image_loss:0.000145288-output_watermark_loss:0.118611485.hdf5
# 122 epochs:123-embedded_image_loss:0.000145399-output_watermark_loss:0.121008806.hdf5
# 123 epochs:124-embedded_image_loss:0.000147318-output_watermark_loss:0.122349061.hdf5
# 124 epochs:125-embedded_image_loss:0.000142198-output_watermark_loss:0.117452286.hdf5
# 125 epochs:126-embedded_image_loss:0.000147927-output_watermark_loss:0.118312612.hdf5
# 126 epochs:127-embedded_image_loss:0.000141750-output_watermark_loss:0.117991850.hdf5
# 127 epochs:128-embedded_image_loss:0.000147924-output_watermark_loss:0.115514159.hdf5
# 128 epochs:129-embedded_image_loss:0.000146942-output_watermark_loss:0.113551632.hdf5
# 129 epochs:130-embedded_image_loss:0.000144443-output_watermark_loss:0.121973552.hdf5
# 130 epochs:131-embedded_image_loss:0.000146724-output_watermark_loss:0.118374877.hdf5
# 131 epochs:132-embedded_image_loss:0.000147272-output_watermark_loss:0.118007042.hdf5
# 132 epochs:133-embedded_image_loss:0.000144180-output_watermark_loss:0.117763877.hdf5
# 133 epochs:134-embedded_image_loss:0.000146520-output_watermark_loss:0.122083426.hdf5
# 134 epochs:135-embedded_image_loss:0.000142220-output_watermark_loss:0.121737421.hdf5
# 135 epochs:136-embedded_image_loss:0.000147492-output_watermark_loss:0.119074389.hdf5
# 136 epochs:137-embedded_image_loss:0.000144766-output_watermark_loss:0.123074047.hdf5
# 137 epochs:138-embedded_image_loss:0.000142852-output_watermark_loss:0.122117773.hdf5
# 138 epochs:139-embedded_image_loss:0.000142331-output_watermark_loss:0.122222424.hdf5
# 139 epochs:140-embedded_image_loss:0.000144787-output_watermark_loss:0.117965177.hdf5
# 140 epochs:141-embedded_image_loss:0.000146636-output_watermark_loss:0.123376183.hdf5
# 141 epochs:142-embedded_image_loss:0.000144988-output_watermark_loss:0.119387358.hdf5
# 142 epochs:143-embedded_image_loss:0.000144737-output_watermark_loss:0.120316871.hdf5
# Model number: 142
# selected model is epochs:143-embedded_image_loss:0.000144737-output_watermark_loss:0.120316871.hdf5

# %% [markdown]
# #### Load model

# %%
model = load_model(
    MODEL_PATH + model_name, 
    custom_objects={
        'HaarWaveLayer2D': HaarWaveLayer2D, 
        'InvHaarWaveLayer2D': InvHaarWaveLayer2D,
        'tf': tf,
        'stupid_function': stupid_function,
        'salt_pepper_function': salt_pepper_function,
        'gaussian_noise_function': gaussian_noise_function,
        'rotation_function': rotation_function,
    }
)
# Out:
# /home/alireza/tapsi_hooni/env/lib/python3.8/site-packages/tensorflow/python/keras/layers/core.py:1059: UserWarning: models.wavetf_model is not loaded, but a Lambda layer uses it. It may cause errors.
#   warnings.warn('{} is not loaded, but a Lambda layer uses it. '
# /home/alireza/tapsi_hooni/env/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:6112: UserWarning: `tf.keras.backend.random_binomial` is deprecated, and will be removed in a future version.Please use `tf.keras.backend.random_bernoulli` instead.
#   warnings.warn('`tf.keras.backend.random_binomial` is deprecated, '

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Evaluation functions

# %%
def mse_cal(input_img, output_img):
    inp_cnv = np.array(input_img).reshape((256,256))
    out_cnv = np.array(output_img).reshape((256,256))
    return mean_squared_error(inp_cnv, out_cnv)


def psnr_cal(input_img, output_img, range_num):
    mse_num = mse_cal(input_img, output_img)
    return 10*math.log10((range_num**2)/mse_num)


def ber_cal(input_wm, output_wm):
    a = np.sum(np.equal(np.round(output_wm),input_wm))
    return 100-(100*a/256)


def evaluate_data(model, data_loader):
    psnr_list = []
    ber_list = []
    for x in data_loader:
        y = model.predict(x)
        for i in range(len(x[0])):
            psnr_list.append(psnr_cal(x[0][i], y[0][i], 1))
            ber_list.append(ber_cal(x[1][i], y[1][i]))
    return np.mean(psnr_list), np.mean(ber_list)

# %% [markdown]
# ### Calculate attacks PSNR and BER

# %%
psnrs = {}
bers = {}

for attack in ATTACKS:
    print(f'{attack} started.')
    psnr, ber = evaluate_data(model, test_data_loaders[attack])
    psnrs[attack] = psnr
    bers[attack] = ber
# Out:
# stupid_attack started.
# 2022-07-22 15:55:23.136373: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-07-22 15:55:23.153478: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 1999965000 Hz
# salt_pepper_attack started.
# gaussian_noise_attack started.
# rotation_attack started.

# %% [markdown]
# ### Show stats

# %%
def show_table(psnrs, bers):
    table = [['attack', 'PSNR', 'BER']]
    for attack in ATTACKS:
        table.append([attack, psnrs[attack], bers[attack]])
    print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))


show_table(psnrs, bers)
# Out:
# ╒═══════════════════════╤═════════╤═══════════╕
# │ attack                │    PSNR │       BER │
# ╞═══════════════════════╪═════════╪═══════════╡
# │ stupid_attack         │ 37.4519 │  0.127344 │
# ├───────────────────────┼─────────┼───────────┤
# │ salt_pepper_attack    │ 37.4519 │  5.17578  │
# ├───────────────────────┼─────────┼───────────┤
# │ gaussian_noise_attack │ 37.4519 │  7.85664  │
# ├───────────────────────┼─────────┼───────────┤
# │ rotation_attack       │ 37.4519 │ 49.898    │
# ╘═══════════════════════╧═════════╧═══════════╛

# %% [markdown]
# ### Check some watermarked images

# %%
sample_output = None
for sample_input in test_data_loaders[ATTACKS[0]]:
    sample_output = model.predict(sample_input)
    break

# %%
fig, axs = plt.subplots(BATCH_SIZE, 3, figsize=(20, 60))
for idx in range(BATCH_SIZE):
    axs[idx][0].imshow(sample_input[0][idx], cmap="gray")
    axs[idx][1].imshow(sample_output[0][idx], cmap="gray")
    axs[idx][2].imshow(abs(sample_input[0][idx] - sample_output[0][idx]), cmap="gray")

# %% [markdown]
# ### Save samples

# %%
for idx in range(BATCH_SIZE):
    input_filename = f'input_{idx}.png'
    output_filename = f'output_{idx}.png'
    diff_filename = f'diff_{idx}.png'
    
    input_image = np.repeat(sample_input[0][idx].numpy(), 3, axis=2) * 256
    output_image = np.repeat(sample_output[0][idx], 3, axis=2) * 256
    diff_image = np.repeat(
        abs(sample_input[0][idx] - sample_output[0][idx]), 3, axis=2) * 256
    
    cv2.imwrite(os.path.join(SAMPLE_IMAGES_OUTPUT, input_filename), input_image)
    cv2.imwrite(os.path.join(SAMPLE_IMAGES_OUTPUT, output_filename), output_image)
    cv2.imwrite(os.path.join(SAMPLE_IMAGES_OUTPUT, diff_filename), diff_image)
